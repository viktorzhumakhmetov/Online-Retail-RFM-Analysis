# %% [markdown]
# ## About Dataset
# A transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.
#
# ### Content
#
# Data Set Characteristics: Multivariate, Sequential, Time-Series
#
# Number of Instances: 541909
#
# Area: Business
#
# Attribute Characteristics: Integer, Real
#
# Number of Attributes: 8
#
# Date Donated: 2015-11-06
#
# Associated Tasks: Classification, Clustering
#
# Missing Values? N/A
#
# Number of Web Hits: 159409
#
# ### Source
#
# Dr Daqing Chen, Director: Public Analytics group. chend '@' lsbu.ac.uk, School of Engineering, London South Bank University, London SE1 0AA, UK.
#
# ### Data Set Information:
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# ### Attribute Information:
#
# InvoiceNo: Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# StockCode: Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.
# Description: Product (item) name. Nominal.
# Quantity: The quantities of each product (item) per transaction. Numeric.
# InvoiceDate: Invice Date and time. Numeric, the day and time when each transaction was generated.
# UnitPrice: Unit price. Numeric, Product price per unit in sterling.
# CustomerID: Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.
# Country: Country name. Nominal, the name of the country where each customer resides.
#
# ### Relevant Papers:
#
# The evolution of direct, data and digital marketing, Richard Webber, Journal of Direct, Data and Digital Marketing Practice (2013) 14, 291â€“309.
# Clustering Experiments on Big Transaction Data for Market Segmentation,
# Ashishkumar Singh, Grace Rumantir, Annie South, Blair Bethwaite, Proceedings of the 2014 International Conference on Big Data Science and Computing.
# A decision-making framework for precision marketing, Zhen You, Yain-Whar Si, Defu Zhang, XiangXiang Zeng, Stephen C.H. Leung c, Tao Li, Expert Systems with Applications, 42 (2015) 3357â€“3367.
#
# ### Citation Request:
#
# Daqing Chen, Sai Liang Sain, and Kun Guo, Data mining for the online retail industry: A case study of RFM model-based customer segmentation using data mining, Journal of Database Marketing and Customer Strategy Management, Vol. 19, No. 3, pp. 197â€“208, 2012 (Published online before print: 27 August 2012. doi: 10.1057/dbm.2012.17).
#
# ### Inspiration
#
# Your data will be in front of the world's largest data science community. What questions do you want to see answered?
#
# ### Link: https://www.kaggle.com/datasets/jihyeseo/online-retail-data-set-from-uci-ml-repo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
from datetime import datetime

# %%
data = pd.read_excel('Online_Retail.xlsx')

# %%
df = data.copy()
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Check duplicated rows number
df.duplicated().sum()
# Out:
# 5268

# %%
# Delete duplicated rows
df = df.drop_duplicates()

# %%
# Missing values
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
# Deleting rows with missing data
df.dropna(inplace=True)

# %%
n_rows = df.shape[0]
print(f'Rows number: {n_rows}')
# Out:
# Rows number: 401604

# %%
# Numerical statistics
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  401604.000000  401604.000000  401604.000000
# mean       12.183273       3.474064   15281.160818
# std       250.283037      69.764035    1714.006089
# min    -80995.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13939.000000
# 50%         5.000000       1.950000   15145.000000
# 75%        12.000000       3.750000   16784.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# Filtering invalid values. Quantity can't be less than zero.
df = df[df['Quantity']>0]

# %%
# Checking data types
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
# Change customer ID from float to string
df.CustomerID = df.CustomerID.astype('str').str.split('.').apply(lambda x: x[0])

# %%
# Adding additional information for analysis
df['Amount'] = df.Quantity * df.UnitPrice
df['Date'] = df.InvoiceDate.dt.date
df['Hour'] = df.InvoiceDate.dt.hour
df['Year_month'] = df.Date.astype('str').str.split('-').apply(lambda x: '-'.join(map(str,x[:2])))

# %%
# All dates in data are from 2011 year except one month. Drop these dates from data.
df = df[df['Year_month']!= '2010-12']

# %%
# Unique values in every rows
cols = list(df.columns)
for col in cols:
    print(f'{col} column unique values: {df[col].nunique()}')
# Out:
# InvoiceNo column unique values: 17136
# StockCode column unique values: 3596
# Description column unique values: 3784
# Quantity column unique values: 295
# InvoiceDate column unique values: 15993
# UnitPrice column unique values: 429
# CustomerID column unique values: 4220
# Country column unique values: 36
# Amount column unique values: 2859
# Date column unique values: 285
# Hour column unique values: 15
# Year_month column unique values: 12

# %%
LTV_average = df.groupby('CustomerID', as_index=False).agg({'Amount':'sum'})\
                .sort_values('Amount', ascending=False).mean().Amount.round(2)
print(f'Average customer LTV: {LTV_average} GBP')
# Out:
# Average customer LTV: 1970.8 GBP

# %%
max_invoice_amount = df.groupby('InvoiceNo', as_index=False)\
                       .agg({'Amount':'sum'})\
                       .sort_values('Amount', ascending=False)\
                       .max().Amount
max_invoice_amount
print(f'Maximal invoice amount: {max_invoice_amount} GBP')
# Out:
# Maximal invoice amount: 168469.6 GBP

# %%
mean_invoice_amount = df.groupby('InvoiceNo', as_index=False)\
                       .agg({'Amount':'sum'})\
                       .sort_values('Amount', ascending=False)\
                       .mean().Amount.round(2)
max_invoice_amount
print(f'Mean invoice amount: {mean_invoice_amount} GBP')
# Out:
# Mean invoice amount: 485.34 GBP

# %%
most_purchased = df.groupby('StockCode', as_index=False)\
                   .agg({'Quantity':'sum'})\
                   .sort_values('Quantity', ascending=False)
desc = df[df.StockCode == most_purchased.StockCode.values[0]].Description.values[0]
quant = most_purchased.Quantity.values[0]
print(f'Top selling item: {desc} ({quant} times sold)')
# Out:
# Top selling item: PAPER CRAFT , LITTLE BIRDIE (80995 times sold)

# %%
most_profitable = df.groupby('Description', as_index=False)\
                  .agg({'Amount':'sum'})\
                  .sort_values('Amount', ascending=False).head(1)
desc = most_profitable.Description.values[0]
amount = most_profitable.Amount.values[0]
print(f'Most profitable item: {desc} ({amount} GBP income)')
# Out:
# Most profitable item: PAPER CRAFT , LITTLE BIRDIE (168469.6 GBP income)

# %%
max_revenue_day = df.groupby('Date', as_index=False)\
                    .agg({'Amount':'sum'})\
                    .sort_values('Amount', ascending=False).head(1)
dt = str(max_revenue_day.Date.values[0])
am = max_revenue_day.Amount.values[0]
print(f'Maximal daily revenue: {am} GBP ({dt})')
# Out:
# Maximal daily revenue: 184329.66 GBP (2011-12-09)

# %%
# Purchase frequency by country
mean_purchase_frequency = df.groupby(['Country','CustomerID'], as_index=False)\
                       .agg({'InvoiceNo':'count'})\
                       .rename(columns={'InvoiceNo':'Frequency'})\
                       .groupby('Country', as_index=False).agg({'Frequency':'mean'}).sort_values('Frequency')

plt.figure(figsize = (12,10))
ax = sns.barplot(y = mean_purchase_frequency.Country, x = mean_purchase_frequency.Frequency, palette='Oranges')
ax.bar_label(ax.containers[0])
plt.title('Average purchase frequency by country')
plt.show()

# %%
# Average purchase by country
countries_mean_purchases = df.groupby('Country', as_index=False)\
                            .agg({'Amount':'mean'})\
                            .sort_values('Amount')
plt.figure(figsize = (12,10))
ax = sns.barplot(y = countries_mean_purchases.Country, x = countries_mean_purchases.Amount, palette='viridis')
ax.bar_label(ax.containers[0])
plt.title('Average purchase amount by country')
plt.show()

# %%
# Total revenue by country
countries_total_revenue = df.groupby('Country', as_index=False)\
                            .agg({'Amount':'sum'})\
                            .sort_values('Amount')
plt.figure(figsize = (12,10))
ax = sns.barplot(y = countries_total_revenue.Country, x = countries_total_revenue.Amount, palette='crest')
plt.title('Total revenue by country')
plt.show()

# %%
# Customers activity peaks
plt.figure(figsize=(12,4))
ax = sns.countplot(x = df.Hour, palette='cool')
ax.bar_label(ax.containers[0])
plt.title('Customers activity peaks by hours\n')
plt.show()

# %%
# Monthly revenue
revenue_by_date = df.groupby('Year_month', as_index=False).agg({'Amount':'sum'})
plt.figure(figsize = (12,4))
sns.lineplot(x = revenue_by_date.Year_month, y = revenue_by_date.Amount, color = 'orange')
plt.title('Monthly revenue')
plt.ylabel('GBP in millions')
plt.xlabel('Month and year')
plt.show()

# %% [markdown]
# ### Analytics report:
#
# * Average customer LTV: 1975.99 GBP
#
# * Maximal invoice amount: 168469.6 GBP
#
# * Mean invoice amount: 486.62 GBP
#
# * Maximal daily revenue: 184349.28 GBP (2011-12-09)
#
# * Top selling item: PAPER CRAFT , LITTLE BIRDIE (80995 times sold).
#
# * Most profitable item: PAPER CRAFT , LITTLE BIRDIE (168469.6 GBP income).
#
# * Customers from Netherlands have the biggest average purchase.
#
# * Customers from UK spent total at least 7 times more than any other country customers.
#
# * Customers from EIRE have maximum purchase frequency.
#
# * Customers activity peak usually happens at 12.00.
#
# * Maximal monthly revenue was in November 2011 (over 1.1 million GBP).

# %% [markdown]
# # RFM analysis

# %%
# Create new dataframe for RFM analysis
RFM_data = df.groupby('CustomerID', as_index=False)\
             .agg({'InvoiceNo':'count','Amount':'sum','InvoiceDate':'max'})
RFM_data['InvoiceDate'] = RFM_data.InvoiceDate.dt.date
today = '2012-01-01'
RFM_data['Recency'] = (pd.to_datetime(today) - pd.to_datetime(RFM_data.InvoiceDate))/np.timedelta64 ( 1 , 'D')
RFM_data.head()
# Out:
#   CustomerID  InvoiceNo    Amount InvoiceDate  Recency
# 0      12346          1  77183.60  2011-01-18    348.0
# 1      12347        151   3598.21  2011-12-07     25.0
# 2      12348         14    904.44  2011-09-25     98.0
# 3      12349         73   1757.55  2011-11-21     41.0
# 4      12350         17    334.40  2011-02-02    333.0

# %%
# Count quantiles 0.33 and 0.66 in Recency, Frequency and Monetary
quantile_33r = RFM_data.Recency.quantile(0.33)
quantile_66r = RFM_data.Recency.quantile(0.66)
quantile_33f = RFM_data.InvoiceNo.quantile(0.33)
quantile_66f = RFM_data.InvoiceNo.quantile(0.66)
quantile_33m = RFM_data.Amount.quantile(0.33)
quantile_66m = RFM_data.Amount.quantile(0.66)

# %%
# Functions for groups splitting
def splitting_r(n):
    if 0 <= n < quantile_33r:
        return 3
    elif quantile_33r <= n < quantile_66r:
        return 2
    elif n >= quantile_66r:
        return 1
    
def splitting_f(n):
    if 0 <= n < quantile_33f:
        return 1
    elif quantile_33f <= n < quantile_66f:
        return 2
    elif n >= quantile_66f:
        return 3
    
def splitting_m(n):
    if 0 <= n < quantile_33m:
        return 1
    elif quantile_33m <= n < quantile_66m:
        return 2
    elif n >= quantile_66m:
        return 3

# %%
# New columns with splitted data
RFM_data['R'] = RFM_data.Recency.apply(splitting_r)
RFM_data['F'] = RFM_data.InvoiceNo.apply(splitting_f)
RFM_data['M'] = RFM_data.Amount.apply(splitting_m)

# %%
# Add RFM scores column
RFM_data['RFM'] = RFM_data['R'] * 100 + RFM_data['F'] * 10 + RFM_data['M']
RFM_data.head()
# Out:
#   CustomerID  InvoiceNo    Amount InvoiceDate  Recency  R  F  M  RFM
# 0      12346          1  77183.60  2011-01-18    348.0  1  1  3  113
# 1      12347        151   3598.21  2011-12-07     25.0  3  3  3  333
# 2      12348         14    904.44  2011-09-25     98.0  2  1  2  212
# 3      12349         73   1757.55  2011-11-21     41.0  3  3  3  333
# 4      12350         17    334.40  2011-02-02    333.0  1  1  1  111

# %%
# Create new RFM_data DataFrame copy and get necessary columns
RFM_description = RFM_data[['CustomerID','R','F','M','RFM']].copy()
RFM_description[['R','F','M']] = RFM_description[['R','F','M']].astype('str')
RFM_description
# Out:
#      CustomerID  R  F  M  RFM
# 0         12346  1  1  3  113
# 1         12347  3  3  3  333
# 2         12348  2  1  2  212
# 3         12349  3  3  3  333
# 4         12350  1  1  1  111
# ...         ... .. .. ..  ...
# 4215      18280  1  1  1  111
# 4216      18281  1  1  1  111
# 4217      18282  3  1  1  311
# 4218      18283  3  3  3  333
# 4219      18287  2  3  3  233
#
# [4220 rows x 5 columns]

# %%
# Dictionaries for data representation
recency_dict = {'1':'less recent','2':'sleeping','3':'recent'}
frequency_dict = {'1':'low frequency','2':'medium frequency','3':'high frequency'}
monetary_dict = {'1':'low monetary','2':'medium monetary','3':'high monetary'}

# %%
# New RFM data representation
RFM_description['R'] = RFM_description['R'].map(recency_dict)
RFM_description['F'] = RFM_description['F'].map(frequency_dict)
RFM_description['M'] = RFM_description['M'].map(monetary_dict)
RFM_description['MR'] = RFM_description['M'] + ' ' + RFM_description['R']
RFM_description
# Out:
#      CustomerID            R               F                M  RFM  \
# 0         12346  less recent   low frequency    high monetary  113
# 1         12347       recent  high frequency    high monetary  333
# 2         12348     sleeping   low frequency  medium monetary  212
# 3         12349       recent  high frequency    high monetary  333
# 4         12350  less recent   low frequency     low monetary  111
# ...         ...          ...             ...              ...  ...
# 4215      18280  less recent   low frequency     low monetary  111
# 4216      18281  less recent   low frequency     low monetary  111
# 4217      18282       recent   low frequency     low monetary  311
# 4218      18283       recent  high frequency    high monetary  333
# 4219      18287     sleeping  high frequency    high monetary  233
#
#                              MR
# 0     high monetary less recent
# 1          high monetary recent
# 2      medium monetary sleeping
# 3          high monetary recent
# 4      low monetary less recent
# ...                         ...
# 4215   low monetary less recent
# 4216   low monetary less recent
# 4217        low monetary recent
# 4218       high monetary recent
# 4219     high monetary sleeping
#
# [4220 rows x 6 columns]

# %%
# Group data by monetary+recency and frequency with clients count aggregation
RFM = RFM_description.groupby(['MR','F'],as_index=False).agg({'CustomerID':'count'})
RFM
# Out:
#                              MR                 F  CustomerID
# 0     high monetary less recent    high frequency         104
# 1     high monetary less recent     low frequency          30
# 2     high monetary less recent  medium frequency          62
# 3          high monetary recent    high frequency         663
# 4          high monetary recent     low frequency          25
# 5          high monetary recent  medium frequency          93
# 6        high monetary sleeping    high frequency         345
# 7        high monetary sleeping     low frequency          17
# 8        high monetary sleeping  medium frequency          96
# 9      low monetary less recent    high frequency          10
# 10     low monetary less recent     low frequency         609
# 11     low monetary less recent  medium frequency         138
# 12          low monetary recent    high frequency          14
# 13          low monetary recent     low frequency         149
# 14          low monetary recent  medium frequency          66
# 15        low monetary sleeping    high frequency          16
# 16        low monetary sleeping     low frequency         275
# 17        low monetary sleeping  medium frequency         116
# 18  medium monetary less recent    high frequency          56
# 19  medium monetary less recent     low frequency         137
# 20  medium monetary less recent  medium frequency         294
# 21       medium monetary recent    high frequency         126
# 22       medium monetary recent     low frequency          49
# 23       medium monetary recent  medium frequency         207
# 24     medium monetary sleeping    high frequency         109
# 25     medium monetary sleeping     low frequency          94
# 26     medium monetary sleeping  medium frequency         320

# %%
# Table transformation with sorting columns and rows
RFM_pivot = RFM.pivot(index='MR',columns='F',values='CustomerID').reset_index()
RFM_pivot = RFM_pivot.set_index('MR')
RFM_pivot = RFM_pivot[['low frequency','medium frequency','high frequency']]
new_index = ['high monetary recent','high monetary sleeping','high monetary less recent',
             'medium monetary recent','medium monetary sleeping','medium monetary less recent',
             'low monetary recent','low monetary sleeping','low monetary less recent']
RFM_pivot = RFM_pivot.reindex(new_index)
RFM_pivot
# Out:
# F                            low frequency  medium frequency  high frequency
# MR
# high monetary recent                    25                93             663
# high monetary sleeping                  17                96             345
# high monetary less recent               30                62             104
# medium monetary recent                  49               207             126
# medium monetary sleeping                94               320             109
# medium monetary less recent            137               294              56
# low monetary recent                    149                66              14
# low monetary sleeping                  275               116              16
# low monetary less recent               609               138              10

# %%
# RFM Heatmap
f,ax = plt.subplots(figsize=(12,8))
sns.heatmap(RFM_pivot,annot=True,
            annot_kws={'size':12},
            fmt='g',cmap='RdYlGn')
plt.title('RFM Heatmap\n')
plt.xlabel('Frequency\n')
plt.ylabel('Monetary + Recency')
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')
plt.show()

# %%
# Split customers to score groups
RFM_scores = RFM_data.groupby('RFM', as_index=False)\
                     .agg({'CustomerID':'count'})\
                     .rename(columns={'CustomerID':'Customers_count'})

# %%
# RFM score groups comparison
plt.figure(figsize = (12,8))
ax = sns.barplot(x = RFM_scores.RFM, y = RFM_scores.Customers_count, palette='RdYlGn')
ax.bar_label(ax.containers[0])
plt.xlabel('Customers loyality grade (RFM score)')
plt.ylabel('Customers count')
plt.suptitle('RFM score groups comparison')
plt.show()
